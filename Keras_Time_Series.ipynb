# %% [markdown]
# <a href="https://colab.research.google.com/github/tsegaimerhawi/pandas/blob/main/Keras_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Time Series Forecasting**

# %% [markdown]
# Time series forecasting involves predicting future values based on previously observed values. It's a crucial aspect of data analysis in numerous fields, enabling organizations and individuals to make informed decisions by projecting past trends into the future. The core importance of time series forecasting lies in its ability to identify patterns, trends, and cycles in historical data, and use these insights to predict future events. This predictive capability is invaluable for planning, budgeting, and managing resources effectively, ensuring that strategies are both proactive and responsive to anticipated changes.

# %% [markdown]
# **Why Keras is Suitable for Time Series Forecasting?**

# %% [markdown]
# Keras is a powerful, user-friendly neural network library written in Python, designed to enable fast experimentation with deep learning. It acts as an interface for the TensorFlow library, combining ease of use with flexibility, and is capable of running on top of TensorFlow.

# %% [markdown]
# 1.   It offers a high-level, intuitive API, making it accessible for beginners while still being robust enough for research and development.
# 2.    It supports a wide range of network architectures, including fully connected, convolutional, and recurrent neural networks (RNNs), essential for handling various time series forecasting tasks.
# 3.    It is optimized for performance, allowing for rapid experimentation and iteration, which is crucial in the development and tuning of predictive models.

# %% [markdown]
# **Setting Up the Development Environment**

# %% [markdown]
# Following the introduction to time series forecasting and the advantages of using Keras for such tasks, we now embark on the practical journey of implementing a time series forecasting model. In this section, we will set up our development environment and prepare our dataset for modeling. The Python libraries and tools we'll use form the backbone of our data processing and model development. Here's a breakdown of the code snippet and its components:

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, activations
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# •	os: This module provides a portable way of using operating system-dependent functionality like reading or writing to a file system.
#
# •	numpy: A fundamental package for scientific computing in Python. It's used for working with arrays and matrices, alongside a collection of mathematical functions to operate on these data structures.
#
# •	pandas: An essential library for data manipulation and analysis. It offers data structures and operations for manipulating numerical tables and time series.
#
# •	matplotlib.pyplot: A plotting library for creating static, interactive, and animated visualizations in Python.
#
# •	sklearn.preprocessing.StandardScaler: A preprocessing module used to standardize features by removing the mean and scaling to unit variance. This is particularly important in neural networks to ensure that all input features have similar scale.
#
# •	tensorflow: An open-source library for numerical computation and machine learning. TensorFlow offers a comprehensive, flexible ecosystem of tools, libraries, and community resources that lets researchers push the state-of-the-art in ML, and developers easily build and deploy ML-powered applications.
#
# •	keras: Integrated into TensorFlow, it simplifies many operations and is used to build and train neural networks. We specifically import submodules for defining layers and activations, along with callbacks like EarlyStopping and ModelCheckpoint for model training optimization.
#
# •	EarlyStopping: Monitors the model's performance on a validation set and stops training when the performance stops improving, preventing overfitting.
#
# •	ModelCheckpoint: Saves the model at specific intervals, allowing us to keep the model at its best performance.

# %% [markdown]
# **Preprocessing data**

# %% [markdown]
# In this section of our notebook, we delve into the critical step of preprocessing our dataset to ensure it's in the optimal format for our time series forecasting model. Our dataset, titled daily-website-visitors.csv, contains daily metrics of website traffic, such as page loads and unique visits. Let's explore the preprocessing steps:

# %%
df = pd.read_csv('daily-website-visitors.csv')

# %% [markdown]
# We start by loading our dataset using pandas, which allows us to work with the data in a tabular form, facilitating data manipulation and analysis. (Help with uploading: https://neptune.ai/blog/google-colab-dealing-with-files)

# %%
df
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# 1                2,297              231
# 2                2,352              278
# 3                2,327              287
# 4                2,130              236
# ...                ...              ...
# 2162             1,373              323
# 2163             1,686              351
# 2164             2,181              457
# 2165             2,184              499
# 2166             1,297              267
#
# [2167 rows x 8 columns]

# %%
for col in ['Page.Loads', 'Unique.Visits', 'First.Time.Visits', 'Returning.Visits']:
    df[col] = df[col].map(lambda x: float(x.replace(",", "")))

# %% [markdown]
# For columns representing numerical values (Page.Loads, Unique.Visits, First.Time.Visits, Returning.Visits), we remove commas and convert the strings to floats. This step is crucial as numeric operations require numerical data types. (Help: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.map.html)

# %%
df
# Out:
#        Row        Day  Day.Of.Week       Date  Page.Loads  Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2146.0         1582.0
# 1        2     Monday            2  9/15/2014      3621.0         2528.0
# 2        3    Tuesday            3  9/16/2014      3698.0         2630.0
# 3        4  Wednesday            4  9/17/2014      3667.0         2614.0
# 4        5   Thursday            5  9/18/2014      3316.0         2366.0
# ...    ...        ...          ...        ...         ...            ...
# 2162  2163   Saturday            7  8/15/2020      2221.0         1696.0
# 2163  2164     Sunday            1  8/16/2020      2724.0         2037.0
# 2164  2165     Monday            2  8/17/2020      3456.0         2638.0
# 2165  2166    Tuesday            3  8/18/2020      3581.0         2683.0
# 2166  2167  Wednesday            4  8/19/2020      2064.0         1564.0
#
#       First.Time.Visits  Returning.Visits
# 0                1430.0             152.0
# 1                2297.0             231.0
# 2                2352.0             278.0
# 3                2327.0             287.0
# 4                2130.0             236.0
# ...                 ...               ...
# 2162             1373.0             323.0
# 2163             1686.0             351.0
# 2164             2181.0             457.0
# 2165             2184.0             499.0
# 2166             1297.0             267.0
#
# [2167 rows x 8 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# Converting the Date column to datetime objects allows for easier manipulation of dates and enables us to set this column as the index of our DataFrame, facilitating time series analysis.

# %%
df.set_index('Date', inplace=True)

# %% [markdown]
# By setting the Date column as the index, we can efficiently perform time-based operations and visualizations on our dataset.

# %%
df["Day.Of.Week.X"], df["Day.Of.Week.Y"] = np.sin(2 * np.pi * df["Day.Of.Week"] / 7), np.cos(2 * np.pi * df["Day.Of.Week"] / 7)
df["Day.Of.Year.X"], df["Day.Of.Year.Y"] = np.sin(2 * np.pi * df.index.day_of_year / 365), np.cos(2 * np.pi * df.index.day_of_year / 365)

# %% [markdown]
# We transform Day.Of.Week and the day of the year into cyclical features using sine and cosine transformations. This approach captures the cyclical nature of these features, enabling the model to understand patterns such as weekends vs. weekdays or seasons in the year. (Help: https://medium.com/@axelazara6/why-we-need-encoding-cyclical-features-79ecc3531232)

# %%
df = df.drop(["Day", "Row", "Day.Of.Week"], axis=1)

# %% [markdown]
# We remove columns that are not necessary for our analysis or that have been replaced by engineered features. This step simplifies our dataset and focuses on the relevant information for forecasting.

# %%
df
# Out:
#             Page.Loads  Unique.Visits  First.Time.Visits  Returning.Visits  \
# Date
# 2014-09-14      2146.0         1582.0             1430.0             152.0
# 2014-09-15      3621.0         2528.0             2297.0             231.0
# 2014-09-16      3698.0         2630.0             2352.0             278.0
# 2014-09-17      3667.0         2614.0             2327.0             287.0
# 2014-09-18      3316.0         2366.0             2130.0             236.0
# ...                ...            ...                ...               ...
# 2020-08-15      2221.0         1696.0             1373.0             323.0
# 2020-08-16      2724.0         2037.0             1686.0             351.0
# 2020-08-17      3456.0         2638.0             2181.0             457.0
# 2020-08-18      3581.0         2683.0             2184.0             499.0
# 2020-08-19      2064.0         1564.0             1297.0             267.0
#
#             Day.Of.Week.X  Day.Of.Week.Y  Day.Of.Year.X  Day.Of.Year.Y
# Date
# 2014-09-14   7.818315e-01       0.623490      -0.958718      -0.284359
# 2014-09-15   9.749279e-01      -0.222521      -0.963471      -0.267814
# 2014-09-16   4.338837e-01      -0.900969      -0.967938      -0.251190
# 2014-09-17  -4.338837e-01      -0.900969      -0.972118      -0.234491
# 2014-09-18  -9.749279e-01      -0.222521      -0.976011      -0.217723
# ...                   ...            ...            ...            ...
# 2020-08-15  -2.449294e-16       1.000000      -0.705584      -0.708627
# 2020-08-16   7.818315e-01       0.623490      -0.717677      -0.696376
# 2020-08-17   9.749279e-01      -0.222521      -0.729558      -0.683919
# 2020-08-18   4.338837e-01      -0.900969      -0.741222      -0.671260
# 2020-08-19  -4.338837e-01      -0.900969      -0.752667      -0.658402
#
# [2167 rows x 8 columns]

# %% [markdown]
# **Splitting, Scaling, and Sequence Handling**

# %% [markdown]
# Having preprocessed our dataset, we now move towards preparing it for modeling. This involves splitting the dataset into training, validation, and test sets, scaling the features, and creating sequences that our model can learn from. These steps are essential for effective model training and evaluation in time series forecasting.

# %% [markdown]
# We **split** our dataset based on time, ensuring that the model is trained on past data and validated and tested on unseen future data. This approach simulates real-world forecasting scenarios:

# %%
train_start = pd.Timestamp("2014")
valid_start = pd.Timestamp("2018")
test_start = pd.Timestamp("2020")
train_df = df[(df.index >= train_start) & (df.index < valid_start)].copy()
valid_df = df[(df.index >= valid_start) & (df.index < test_start)].copy()
test_df = df[(df.index >= test_start)].copy()

# %% [markdown]
# By dividing the data this way, we can train the model on data from 2014 to 2017, validate its performance on data from 2018 to 2019, and finally test it on data from 2020 onwards.

# %% [markdown]
# **Scaling** is a critical preprocessing step in many machine learning workflows, especially for neural networks. It ensures that all input features and target variables have a similar scale, which can significantly impact the model's convergence speed and overall performance:

# %%
scaler_input = StandardScaler()
scaler_output = StandardScaler()

scaled_train = scaler_input.fit_transform(train_df)
target_train = scaler_output.fit_transform(train_df[["First.Time.Visits"]])
scaled_valid = scaler_input.transform(valid_df)
target_valid = scaler_output.transform(valid_df[["First.Time.Visits"]])
scaled_test = scaler_input.transform(test_df)
target_test = scaler_output.transform(test_df[["First.Time.Visits"]])

# %% [markdown]
# Here, we use StandardScaler to standardize our features and target variable, ensuring they're centered around zero with a standard deviation of one.

# %% [markdown]
# For time series forecasting, especially with neural networks like RNNs or LSTMs, it's beneficial to frame the dataset into **sequences of a specific length**. This structure allows the model to learn from a fixed number of past observations to predict future values:

# %%
def process_Xy(raw_X: np.array, raw_y: np.array, lookback: int) -> np.array:
        X = np.empty(shape=(raw_X.shape[0] - lookback, lookback , raw_X.shape[1]), dtype=np.float32)
        y = np.empty(shape=(raw_y.shape[0] - lookback), dtype=np.float32)

        target_index = 0
        for i in range(lookback, raw_X.shape[0]):
            X[target_index] = raw_X[i - lookback : i]
            y[target_index] = raw_y[i]
            target_index += 1

        return X.copy(), y.copy()

# %% [markdown]
# By creating a process_Xy function, we generate input sequences (X) and corresponding targets (y) for our model, using a lookback period that defines how many previous time steps the model should consider for predicting the next step.

# %%
lookback = 10
train_X, train_y = process_Xy(scaled_train, target_train, lookback=lookback)
valid_X, valid_y = process_Xy(scaled_valid, target_valid, lookback=lookback)
test_X, test_y = process_Xy(scaled_test, target_test, lookback=lookback)
# Out:
# <ipython-input-15-fa7f67de0456>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[target_index] = raw_y[i]

# %% [markdown]
# Setting lookback to 10 days means the model will use the past 10 days of data to make predictions. This setup provides a practical foundation for our model to learn and predict future values based on historical sequences of data.

# %% [markdown]
# **Model Building, Training, Validating, Testing, and Visualizing**

# %% [markdown]
# After preparing and preprocessing our data, the next crucial steps are building the forecasting model, training it on the training set, validating its performance on the validation set, and testing its final predictive capability on the test set. We will also visualize the model's training process and compare its predictions with the actual data. Let's delve into each of these steps:

# %% [markdown]
# We construct our model using Keras's Sequential API, which allows us to linearly stack layers. Here, we utilize an LSTM (Long Short-Term Memory) layer followed by a Dense layer for output:

# %%
model = keras.Sequential(
    [
        layers.LSTM(16, activation="relu", input_shape = train_X.shape[1:]),
        layers.Dense(1),
    ]
)

# %% [markdown]
# The LSTM layer with 16 units is chosen for its ability to remember long-term dependencies, a crucial feature for time series data.
#
# The input_shape argument is set to the shape of our training data, ensuring the model can process the input sequences correctly.
#
# A Dense layer with a single unit is used to output the forecasted value.

# %%
model.compile(loss='MeanSquaredError', optimizer='Adam')

# %% [markdown]
# We compile the model using the Mean Squared Error loss function, suitable for regression tasks like ours, and the Adam optimizer, known for its efficiency in adjusting the model's weights.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16)                1600
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 1617 (6.32 KB)
# Trainable params: 1617 (6.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Viewing the model summary provides insight into the architecture, including the number of parameters to be trained.

# %% [markdown]
# We train the model with the EarlyStopping callback to prevent overfitting, stopping the training if the validation loss does not improve for 10 consecutive epochs:

# %%
callbacks = [EarlyStopping(monitor="val_loss", patience=10)]

# %%
history = model.fit(
            train_X,
            train_y,
            validation_data=(valid_X, valid_y),
            batch_size=16,
            epochs=100,
            callbacks=callbacks,
            shuffle=True,
            verbose=True,
        )
# Out:
# Epoch 1/100
# 75/75 [==============================] - 3s 11ms/step - loss: 0.6311 - val_loss: 0.2952
# Epoch 2/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1937 - val_loss: 0.1327
# Epoch 3/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1256 - val_loss: 0.1101
# Epoch 4/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1042 - val_loss: 0.1008
# Epoch 5/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0877 - val_loss: 0.0807
# Epoch 6/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0688 - val_loss: 0.0691
# Epoch 7/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0574 - val_loss: 0.0665
# Epoch 8/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0511 - val_loss: 0.0578
# Epoch 9/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0446 - val_loss: 0.0537
# Epoch 10/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0432 - val_loss: 0.0636
# Epoch 11/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0428 - val_loss: 0.0498
# Epoch 12/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0398 - val_loss: 0.0515
# Epoch 13/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0394 - val_loss: 0.0574
# Epoch 14/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0402 - val_loss: 0.0515
# Epoch 15/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0407 - val_loss: 0.0511
# Epoch 16/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0391 - val_loss: 0.0462
# Epoch 17/100
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0380 - val_loss: 0.0521
# Epoch 18/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0389 - val_loss: 0.0477
# Epoch 19/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0359 - val_loss: 0.0459
# Epoch 20/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0358 - val_loss: 0.0469
# Epoch 21/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0359 - val_loss: 0.0486
# Epoch 22/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0364 - val_loss: 0.0454
# Epoch 23/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0353 - val_loss: 0.0458
# Epoch 24/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0349 - val_loss: 0.0492
# Epoch 25/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0340 - val_loss: 0.0495
# Epoch 26/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0352 - val_loss: 0.0472
# Epoch 27/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0341 - val_loss: 0.0464
# Epoch 28/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0330 - val_loss: 0.0453
# Epoch 29/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0352 - val_loss: 0.0463
# Epoch 30/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0338 - val_loss: 0.0436
# Epoch 31/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0333 - val_loss: 0.0514
# Epoch 32/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0331 - val_loss: 0.0479
# Epoch 33/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0338 - val_loss: 0.0524
# Epoch 34/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0336 - val_loss: 0.0452
# Epoch 35/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0327 - val_loss: 0.0462
# Epoch 36/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0335 - val_loss: 0.0466
# Epoch 37/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0324 - val_loss: 0.0436
# Epoch 38/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0321 - val_loss: 0.0455
# Epoch 39/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0329 - val_loss: 0.0518
# Epoch 40/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0321 - val_loss: 0.0455
# Epoch 41/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0319 - val_loss: 0.0442
# Epoch 42/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0320 - val_loss: 0.0465
# Epoch 43/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0317 - val_loss: 0.0459
# Epoch 44/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0304 - val_loss: 0.0434
# Epoch 45/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0317 - val_loss: 0.0456
# Epoch 46/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0322 - val_loss: 0.0472
# Epoch 47/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0309 - val_loss: 0.0476
# Epoch 48/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0305 - val_loss: 0.0407
# Epoch 49/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0310 - val_loss: 0.0431
# Epoch 50/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0323 - val_loss: 0.0461
# Epoch 51/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0315 - val_loss: 0.0469
# Epoch 52/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0303 - val_loss: 0.0458
# Epoch 53/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0312 - val_loss: 0.0419
# Epoch 54/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0303 - val_loss: 0.0425
# Epoch 55/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0290 - val_loss: 0.0440
# Epoch 56/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0306 - val_loss: 0.0452
# Epoch 57/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0306 - val_loss: 0.0491
# Epoch 58/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0302 - val_loss: 0.0428

# %% [markdown]
# Visualizing Training and Validation Loss

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# This plot helps us understand how the model's performance improved over time and whether it is overfitting or underfitting the training data.

# %% [markdown]
# Finally, we use the model to make predictions on the test set and visualize these predictions alongside the actual data:

# %%
pred = model.predict(test_X)
plt.figure(figsize=(10, 6))
plt.plot(test_df["First.Time.Visits"], label="Real", color='blue')
plt.plot(pd.DataFrame(index=test_df.index[lookback:], data=scaler_output.inverse_transform(pred)), label="Predicted", color='red')
plt.xticks(rotation=45)
plt.title('Actual vs Predicted First Time Visits')
plt.xlabel('Date')
plt.ylabel('First Time Visits')
plt.legend()
plt.show()
# Out:
# 7/7 [==============================] - 1s 6ms/step

# %% [markdown]
# The predicted values are scaled back to their original range using scaler_output.inverse_transform for a direct comparison with the actual data.
# This visualization allows us to assess the model's predictive accuracy visually, comparing its forecasts against the true outcomes.

# %% [markdown]
# **Exercises to Complete:**
#
#
# 1.   Repeat the same process for Page.Loads, Unique.Visits, and Returning.Visits.
# 2.   For Page.Loads, visualize both the actual and the predicted values for the validation set as well.
# 3.   Experiment with a GRU (Gated Recurrent Unit)-based network for Page.Loads, and try implementing a network with multiple Dense layers after the GRU layer.
# 4.   Conduct the forecasting process for the meantemp column in DailyDelhiClimate.csv. Note that the meanpressure column contains outliers; filter these out first to ensure numerical stability. Set the training, validation, and testing periods to start in 2013, 2016, and 2017, respectively. Only include cyclical features for "day-of-the-year," omitting "day-of-the-week".
# +1.  Why can we omit the "day-of-the-week" analysis?

# %% [markdown]
# **Exercise 1**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, activations
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Place for your code


df = pd.read_csv('daily-website-visitors.csv')
for col in ['Page.Loads', 'Unique.Visits', 'First.Time.Visits', 'Returning.Visits']:
    df[col] = df[col].map(lambda x: float(x.replace(",", "")))

df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

df["Day.Of.Week.X"], df["Day.Of.Week.Y"] = np.sin(2 * np.pi * df["Day.Of.Week"] / 7), np.cos(2 * np.pi * df["Day.Of.Week"] / 7)
df["Day.Of.Year.X"], df["Day.Of.Year.Y"] = np.sin(2 * np.pi * df.index.day_of_year / 365), np.cos(2 * np.pi * df.index.day_of_year / 365)

df = df.drop(["Day", "Row", "Day.Of.Week"], axis=1)


train_start = pd.Timestamp("2014")
valid_start = pd.Timestamp("2018")
test_start = pd.Timestamp("2020")
train_df = df[(df.index >= train_start) & (df.index < valid_start)].copy()
valid_df = df[(df.index >= valid_start) & (df.index < test_start)].copy()
test_df = df[(df.index >= test_start)].copy()




def scaler(target_feature):
    scaler_input = StandardScaler()
    scaler_output = StandardScaler()

    scaled_train = scaler_input.fit_transform(train_df)
    target_train = scaler_output.fit_transform(train_df[[target_feature]])
    scaled_valid = scaler_input.transform(valid_df)
    target_valid = scaler_output.transform(valid_df[[target_feature]])
    scaled_test = scaler_input.transform(test_df)
    target_test = scaler_output.transform(test_df[[target_feature]])

    return scaled_train,target_train,scaled_valid,target_valid,scaled_test,target_test, scaler_output

def process_Xy(raw_X: np.array, raw_y: np.array, lookback: int) -> np.array:
        X = np.empty(shape=(raw_X.shape[0] - lookback, lookback , raw_X.shape[1]), dtype=np.float32)
        y = np.empty(shape=(raw_y.shape[0] - lookback), dtype=np.float32)

        target_index = 0
        for i in range(lookback, raw_X.shape[0]):
            X[target_index] = raw_X[i - lookback : i]
            y[target_index] = raw_y[i]
            target_index += 1

        return X.copy(), y.copy()




def model_definition(train_X,train_y,valid_X,valid_y):


    model = keras.Sequential(
        [
            layers.LSTM(16, activation="relu", input_shape = train_X.shape[1:]),
            layers.Dense(1),
        ]
    )
    model.compile(loss='MeanSquaredError', optimizer='Adam')
    callbacks = [EarlyStopping(monitor="val_loss", patience=10)]
    history = model.fit(
            train_X,
            train_y,
            validation_data=(valid_X, valid_y),
            batch_size=16,
            epochs=100,
            callbacks=callbacks,
            shuffle=True,
            verbose=True,
        )
    return model, history
features = ['Page.Loads', 'Unique.Visits', 'Returning.Visits']
for targ_feature in features:
  scaled_train,target_train,scaled_valid,target_valid,scaled_test,target_test,scaler_output = scaler(targ_feature)
  lookback = 10
  train_X, train_y = process_Xy(scaled_train, target_train, lookback=lookback)
  valid_X, valid_y = process_Xy(scaled_valid, target_valid, lookback=lookback)
  test_X, test_y = process_Xy(scaled_test, target_test, lookback=lookback)
  model, history = model_definition(train_X, train_y,valid_X, valid_y)
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model Training and Validation Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()
  pred = model.predict(test_X)
  plt.figure(figsize=(10, 6))
  plt.plot(test_df[targ_feature], label="Real", color='blue')
  plt.plot(pd.DataFrame(index=test_df.index[lookback:], data=scaler_output.inverse_transform(pred)), label="Predicted", color='red')
  plt.xticks(rotation=45)
  plt.title('Actual vs Predicted' + targ_feature)
  plt.xlabel('Date')
  plt.ylabel(targ_feature)
  plt.legend()
  plt.show()
# Out:
# Epoch 1/100
# <ipython-input-37-19055dddc73c>:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[target_index] = raw_y[i]
# 75/75 [==============================] - 3s 10ms/step - loss: 0.8666 - val_loss: 0.4613
# Epoch 2/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.2766 - val_loss: 0.2165
# Epoch 3/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1782 - val_loss: 0.2046
# Epoch 4/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1437 - val_loss: 0.1483
# Epoch 5/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1161 - val_loss: 0.1218
# Epoch 6/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0911 - val_loss: 0.1113
# Epoch 7/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0736 - val_loss: 0.0870
# Epoch 8/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0646 - val_loss: 0.0963
# Epoch 9/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0584 - val_loss: 0.0785
# Epoch 10/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0534 - val_loss: 0.0767
# Epoch 11/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0523 - val_loss: 0.0662
# Epoch 12/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0496 - val_loss: 0.0671
# Epoch 13/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0482 - val_loss: 0.0714
# Epoch 14/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0460 - val_loss: 0.0640
# Epoch 15/100
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0463 - val_loss: 0.0603
# Epoch 16/100
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0447 - val_loss: 0.0695
# Epoch 17/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0445 - val_loss: 0.0626
# Epoch 18/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0425 - val_loss: 0.0663
# Epoch 19/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0422 - val_loss: 0.0578
# Epoch 20/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0404 - val_loss: 0.0615
# Epoch 21/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0412 - val_loss: 0.0606
# Epoch 22/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0412 - val_loss: 0.0580
# Epoch 23/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0394 - val_loss: 0.0646
# Epoch 24/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0412 - val_loss: 0.0646
# Epoch 25/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0386 - val_loss: 0.0676
# Epoch 26/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0388 - val_loss: 0.0549
# Epoch 27/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0377 - val_loss: 0.0646
# Epoch 28/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0384 - val_loss: 0.0590
# Epoch 29/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0397 - val_loss: 0.0804
# Epoch 30/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0388 - val_loss: 0.0573
# Epoch 31/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0366 - val_loss: 0.0656
# Epoch 32/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0400 - val_loss: 0.0557
# Epoch 33/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0373 - val_loss: 0.0549
# Epoch 34/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0367 - val_loss: 0.0579
# Epoch 35/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0376 - val_loss: 0.0661
# Epoch 36/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0379 - val_loss: 0.0653
# Epoch 37/100
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0361 - val_loss: 0.0558
# Epoch 38/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0361 - val_loss: 0.0719
# Epoch 39/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0355 - val_loss: 0.0506
# Epoch 40/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0369 - val_loss: 0.0530
# Epoch 41/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0377 - val_loss: 0.0585
# Epoch 42/100
# 75/75 [==============================] - 2s 23ms/step - loss: 0.0367 - val_loss: 0.0652
# Epoch 43/100
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0347 - val_loss: 0.0567
# Epoch 44/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0384 - val_loss: 0.0638
# Epoch 45/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0352 - val_loss: 0.0661
# Epoch 46/100
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0348 - val_loss: 0.0634
# Epoch 47/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0354 - val_loss: 0.0585
# Epoch 48/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0348 - val_loss: 0.0618
# Epoch 49/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0344 - val_loss: 0.0622
# 7/7 [==============================] - 0s 3ms/step
# Epoch 1/100
# <ipython-input-37-19055dddc73c>:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[target_index] = raw_y[i]
# 75/75 [==============================] - 2s 13ms/step - loss: 0.4604 - val_loss: 0.2372
# Epoch 2/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.1880 - val_loss: 0.1525
# Epoch 3/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.1302 - val_loss: 0.1353
# Epoch 4/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.1011 - val_loss: 0.0889
# Epoch 5/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0713 - val_loss: 0.0698
# Epoch 6/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0566 - val_loss: 0.0581
# Epoch 7/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0490 - val_loss: 0.0643
# Epoch 8/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0460 - val_loss: 0.0641
# Epoch 9/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0444 - val_loss: 0.0578
# Epoch 10/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0420 - val_loss: 0.0489
# Epoch 11/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0423 - val_loss: 0.0550
# Epoch 12/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0397 - val_loss: 0.0543
# Epoch 13/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0385 - val_loss: 0.0524
# Epoch 14/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0383 - val_loss: 0.0472
# Epoch 15/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0377 - val_loss: 0.0465
# Epoch 16/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0383 - val_loss: 0.0471
# Epoch 17/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0385 - val_loss: 0.0514
# Epoch 18/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0361 - val_loss: 0.0517
# Epoch 19/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0375 - val_loss: 0.0520
# Epoch 20/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0365 - val_loss: 0.0508
# Epoch 21/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0355 - val_loss: 0.0489
# Epoch 22/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0346 - val_loss: 0.0435
# Epoch 23/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0346 - val_loss: 0.0445
# Epoch 24/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0342 - val_loss: 0.0444
# Epoch 25/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0340 - val_loss: 0.0447
# Epoch 26/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0343 - val_loss: 0.0438
# Epoch 27/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0337 - val_loss: 0.0444
# Epoch 28/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0340 - val_loss: 0.0468
# Epoch 29/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0329 - val_loss: 0.0445
# Epoch 30/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0345 - val_loss: 0.0436
# Epoch 31/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0318 - val_loss: 0.0388
# Epoch 32/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0323 - val_loss: 0.0452
# Epoch 33/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0329 - val_loss: 0.0448
# Epoch 34/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0320 - val_loss: 0.0458
# Epoch 35/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0315 - val_loss: 0.0379
# Epoch 36/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0393
# Epoch 37/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0317 - val_loss: 0.0468
# Epoch 38/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0327 - val_loss: 0.0412
# Epoch 39/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0306 - val_loss: 0.0422
# Epoch 40/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0313 - val_loss: 0.0420
# Epoch 41/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0309 - val_loss: 0.0420
# Epoch 42/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0308 - val_loss: 0.0428
# Epoch 43/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0305 - val_loss: 0.0390
# Epoch 44/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0308 - val_loss: 0.0424
# Epoch 45/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0304 - val_loss: 0.0389
# 7/7 [==============================] - 0s 4ms/step
# <ipython-input-37-19055dddc73c>:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[target_index] = raw_y[i]
# Epoch 1/100
# 75/75 [==============================] - 2s 10ms/step - loss: 0.6377 - val_loss: 0.3929
# Epoch 2/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.2522 - val_loss: 0.1922
# Epoch 3/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1644 - val_loss: 0.1711
# Epoch 4/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1362 - val_loss: 0.1289
# Epoch 5/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1134 - val_loss: 0.1236
# Epoch 6/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0932 - val_loss: 0.0947
# Epoch 7/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0779 - val_loss: 0.0943
# Epoch 8/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0688 - val_loss: 0.0753
# Epoch 9/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0584 - val_loss: 0.0670
# Epoch 10/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0537 - val_loss: 0.0713
# Epoch 11/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0508 - val_loss: 0.0629
# Epoch 12/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0501 - val_loss: 0.0596
# Epoch 13/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0482 - val_loss: 0.0590
# Epoch 14/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0459 - val_loss: 0.0602
# Epoch 15/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0470 - val_loss: 0.0620
# Epoch 16/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0456 - val_loss: 0.0593
# Epoch 17/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0456 - val_loss: 0.0633
# Epoch 18/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0444 - val_loss: 0.0629
# Epoch 19/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0447 - val_loss: 0.0542
# Epoch 20/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0455 - val_loss: 0.0537
# Epoch 21/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0446 - val_loss: 0.0560
# Epoch 22/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0445 - val_loss: 0.0561
# Epoch 23/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0426 - val_loss: 0.0599
# Epoch 24/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0432 - val_loss: 0.0538
# Epoch 25/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0415 - val_loss: 0.0543
# Epoch 26/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0415 - val_loss: 0.0610
# Epoch 27/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0428 - val_loss: 0.0594
# Epoch 28/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0410 - val_loss: 0.0540
# Epoch 29/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0410 - val_loss: 0.0535
# Epoch 30/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0403 - val_loss: 0.0677
# Epoch 31/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0416 - val_loss: 0.0523
# Epoch 32/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0400 - val_loss: 0.0578
# Epoch 33/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0405 - val_loss: 0.0568
# Epoch 34/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0410 - val_loss: 0.0529
# Epoch 35/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0406 - val_loss: 0.0514
# Epoch 36/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0393 - val_loss: 0.0524
# Epoch 37/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0399 - val_loss: 0.0561
# Epoch 38/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0403 - val_loss: 0.0555
# Epoch 39/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0388 - val_loss: 0.0547
# Epoch 40/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0396 - val_loss: 0.0537
# Epoch 41/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0379 - val_loss: 0.0556
# Epoch 42/100
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0385 - val_loss: 0.0517
# Epoch 43/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0383 - val_loss: 0.0514
# Epoch 44/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0398 - val_loss: 0.0549
# Epoch 45/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0381 - val_loss: 0.0561
# 7/7 [==============================] - 0s 3ms/step

# %% [markdown]
# **Exercise 2**

# %%
#Unique.Visits
features = ['Page.Loads', 'Unique.Visits', 'Returning.Visits']
targ_feature = features[0]
scaled_train,target_train,scaled_valid,target_valid,scaled_test,target_test,scaler_output = scaler(targ_feature)
lookback = 10
train_X, train_y = process_Xy(scaled_train, target_train, lookback=lookback)
valid_X, valid_y = process_Xy(scaled_valid, target_valid, lookback=lookback)
test_X, test_y = process_Xy(scaled_test, target_test, lookback=lookback)
model, history = model_definition(train_X, train_y,valid_X, valid_y)
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Model Training and Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()
# pred = model.predict(test_X)
# plt.figure(figsize=(10, 6))
# plt.plot(test_df[targ_feature], label="Real", color='blue')
# plt.plot(pd.DataFrame(index=test_df.index[lookback:], data=scaler_output.inverse_transform(pred)), label="Predicted", color='red')
# plt.xticks(rotation=45)
# plt.title('Actual vs Predicted' + targ_feature)
# plt.xlabel('Date')
# plt.ylabel(targ_feature)
# plt.legend()
# plt.show()
pred_valid = model.predict(valid_X)
plt.figure(figsize=(10, 6))
plt.plot(valid_df[targ_feature], label="Real", color='blue')
plt.plot(pd.DataFrame(index=valid_df.index[lookback:], data=scaler_output.inverse_transform(pred_valid)), label="Predicted", color='red')
plt.xticks(rotation=45)
plt.title('Validation value vs Predicted' + targ_feature)
plt.xlabel('Date')
plt.ylabel(targ_feature)
plt.legend()
plt.show()
# Out:
# <ipython-input-37-19055dddc73c>:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[target_index] = raw_y[i]
# Epoch 1/100
# 75/75 [==============================] - 2s 10ms/step - loss: 0.6244 - val_loss: 0.4043
# Epoch 2/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.2320 - val_loss: 0.2435
# Epoch 3/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1621 - val_loss: 0.1845
# Epoch 4/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1358 - val_loss: 0.1678
# Epoch 5/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1203 - val_loss: 0.1491
# Epoch 6/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1004 - val_loss: 0.1640
# Epoch 7/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0849 - val_loss: 0.1230
# Epoch 8/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0699 - val_loss: 0.1244
# Epoch 9/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0577 - val_loss: 0.1011
# Epoch 10/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0505 - val_loss: 0.1057
# Epoch 11/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0482 - val_loss: 0.0946
# Epoch 12/100
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0454 - val_loss: 0.0922
# Epoch 13/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0428 - val_loss: 0.0806
# Epoch 14/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0435 - val_loss: 0.0748
# Epoch 15/100
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0420 - val_loss: 0.0840
# Epoch 16/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0409 - val_loss: 0.1061
# Epoch 17/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0426 - val_loss: 0.0824
# Epoch 18/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0392 - val_loss: 0.0694
# Epoch 19/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0390 - val_loss: 0.0712
# Epoch 20/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0379 - val_loss: 0.0767
# Epoch 21/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0390 - val_loss: 0.0654
# Epoch 22/100
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0377 - val_loss: 0.0665
# Epoch 23/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0373 - val_loss: 0.0630
# Epoch 24/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0374 - val_loss: 0.0744
# Epoch 25/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0377 - val_loss: 0.0737
# Epoch 26/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0372 - val_loss: 0.0724
# Epoch 27/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0375 - val_loss: 0.0715
# Epoch 28/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0637
# Epoch 29/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0373 - val_loss: 0.0757
# Epoch 30/100
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0363 - val_loss: 0.0784
# Epoch 31/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0366 - val_loss: 0.0836
# Epoch 32/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0357 - val_loss: 0.0654
# Epoch 33/100
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0363 - val_loss: 0.0660
# 23/23 [==============================] - 0s 2ms/step

# %% [markdown]
# **Exercise 3**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, activations
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Place for your code


df = pd.read_csv('daily-website-visitors.csv')
for col in ['Page.Loads', 'Unique.Visits', 'First.Time.Visits', 'Returning.Visits']:
    df[col] = df[col].map(lambda x: float(x.replace(",", "")))

df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

df["Day.Of.Week.X"], df["Day.Of.Week.Y"] = np.sin(2 * np.pi * df["Day.Of.Week"] / 7), np.cos(2 * np.pi * df["Day.Of.Week"] / 7)
df["Day.Of.Year.X"], df["Day.Of.Year.Y"] = np.sin(2 * np.pi * df.index.day_of_year / 365), np.cos(2 * np.pi * df.index.day_of_year / 365)

df = df.drop(["Day", "Row", "Day.Of.Week"], axis=1)


train_start = pd.Timestamp("2014")
valid_start = pd.Timestamp("2018")
test_start = pd.Timestamp("2020")
train_df = df[(df.index >= train_start) & (df.index < valid_start)].copy()
valid_df = df[(df.index >= valid_start) & (df.index < test_start)].copy()
test_df = df[(df.index >= test_start)].copy()




def scaler(target_feature):
    scaler_input = StandardScaler()
    scaler_output = StandardScaler()

    scaled_train = scaler_input.fit_transform(train_df)
    target_train = scaler_output.fit_transform(train_df[[target_feature]])
    scaled_valid = scaler_input.transform(valid_df)
    target_valid = scaler_output.transform(valid_df[[target_feature]])
    scaled_test = scaler_input.transform(test_df)
    target_test = scaler_output.transform(test_df[[target_feature]])

    return scaled_train,target_train,scaled_valid,target_valid,scaled_test,target_test, scaler_output

def process_Xy(raw_X: np.array, raw_y: np.array, lookback: int) -> np.array:
        X = np.empty(shape=(raw_X.shape[0] - lookback, lookback , raw_X.shape[1]), dtype=np.float32)
        y = np.empty(shape=(raw_y.shape[0] - lookback), dtype=np.float32)

        target_index = 0
        for i in range(lookback, raw_X.shape[0]):
            X[target_index] = raw_X[i - lookback : i]
            y[target_index] = raw_y[i]
            target_index += 1

        return X.copy(), y.copy()



def gru_model_definition(train_X, train_y, valid_X, valid_y):
    # GRU Model
    model = keras.Sequential([
        layers.GRU(16, activation='relu', input_shape=train_X.shape[1:], return_sequences=True),
        layers.GRU(8, activation='relu', return_sequences=False),
        layers.Dense(16, activation='relu'),
        layers.Dense(8, activation='relu'),
        layers.Dense(1)
    ])

    model.compile(loss='mean_squared_error', optimizer='adam')


    callbacks = [EarlyStopping(monitor='val_loss', patience=10)]

    history = model.fit(
        train_X,
        train_y,
        validation_data=(valid_X, valid_y),
        batch_size=16,
        epochs=100,
        callbacks=callbacks,
        shuffle=True,
        verbose=True,
    )

    return model, history

features = ['Page.Loads', 'Unique.Visits', 'Returning.Visits']
targ_feature = features[0]
scaled_train,target_train,scaled_valid,target_valid,scaled_test,target_test,scaler_output = scaler(targ_feature)
lookback = 10
train_X, train_y = process_Xy(scaled_train, target_train, lookback=lookback)
valid_X, valid_y = process_Xy(scaled_valid, target_valid, lookback=lookback)
test_X, test_y = process_Xy(scaled_test, target_test, lookback=lookback)
model, history = gru_model_definition(train_X, train_y,valid_X, valid_y)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
pred = model.predict(test_X)
plt.figure(figsize=(10, 6))
plt.plot(test_df[targ_feature], label="Real", color='blue')
plt.plot(pd.DataFrame(index=test_df.index[lookback:], data=scaler_output.inverse_transform(pred)), label="Predicted", color='red')
plt.xticks(rotation=45)
plt.title('Actual vs Predicted' + targ_feature)
plt.xlabel('Date')
plt.ylabel(targ_feature)
plt.legend()
plt.show()
# Out:
# <ipython-input-24-310b71e389a7>:57: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[target_index] = raw_y[i]
# Epoch 1/100
# 75/75 [==============================] - 6s 19ms/step - loss: 0.8679 - val_loss: 0.7610
# Epoch 2/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.4199 - val_loss: 0.2325
# Epoch 3/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.1440 - val_loss: 0.1433
# Epoch 4/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0884 - val_loss: 0.1058
# Epoch 5/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0721 - val_loss: 0.0931
# Epoch 6/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0642 - val_loss: 0.0901
# Epoch 7/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0575 - val_loss: 0.0990
# Epoch 8/100
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0529 - val_loss: 0.0746
# Epoch 9/100
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0488 - val_loss: 0.0823
# Epoch 10/100
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0490 - val_loss: 0.0739
# Epoch 11/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0449 - val_loss: 0.0627
# Epoch 12/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0436 - val_loss: 0.0672
# Epoch 13/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0430 - val_loss: 0.0695
# Epoch 14/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0421 - val_loss: 0.0714
# Epoch 15/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0705
# Epoch 16/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0411 - val_loss: 0.0726
# Epoch 17/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0403 - val_loss: 0.0574
# Epoch 18/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0413 - val_loss: 0.0633
# Epoch 19/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0402 - val_loss: 0.0576
# Epoch 20/100
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0388 - val_loss: 0.0645
# Epoch 21/100
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0384 - val_loss: 0.0572
# Epoch 22/100
# 75/75 [==============================] - 1s 14ms/step - loss: 0.0387 - val_loss: 0.0578
# Epoch 23/100
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0384 - val_loss: 0.0617
# Epoch 24/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0372 - val_loss: 0.0822
# Epoch 25/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0379 - val_loss: 0.0598
# Epoch 26/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0369 - val_loss: 0.0614
# Epoch 27/100
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0367 - val_loss: 0.0642
# Epoch 28/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0382 - val_loss: 0.0605
# Epoch 29/100
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0371 - val_loss: 0.0648
# Epoch 30/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0366 - val_loss: 0.0555
# Epoch 31/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0348 - val_loss: 0.0595
# Epoch 32/100
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0361 - val_loss: 0.0536
# Epoch 33/100
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0358 - val_loss: 0.0528
# Epoch 34/100
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0353 - val_loss: 0.0562
# Epoch 35/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0355 - val_loss: 0.0671
# Epoch 36/100
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0360 - val_loss: 0.0578
# Epoch 37/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0342 - val_loss: 0.0599
# Epoch 38/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0346 - val_loss: 0.0703
# Epoch 39/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0329 - val_loss: 0.0688
# Epoch 40/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0337 - val_loss: 0.0742
# Epoch 41/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0339 - val_loss: 0.0581
# Epoch 42/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0330 - val_loss: 0.0542
# Epoch 43/100
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0333 - val_loss: 0.0604
# 7/7 [==============================] - 1s 6ms/step

# %% [markdown]
# **Exercise 4**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, activations
from keras.callbacks import EarlyStopping, ModelCheckpoint
from scipy.stats import zscore

df = pd.read_csv('DailyDelhiClimate.csv')

df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
print(len(df))
meanpressure_column = df['meanpressure']

z_scores = zscore(meanpressure_column)

threshold = 2

outliers = meanpressure_column[abs(z_scores) > threshold]
print("Outliers:")
print(outliers)

outlier_mask = abs(z_scores) > threshold
# Removing the outliers
df = df[~outlier_mask]




df["Day.Of.Year.X"], df["Day.Of.Year.Y"] = np.sin(2 * np.pi * df.index.day_of_year / 365.2425), np.cos(2 * np.pi * df.index.day_of_year / 365.2425)
df.head(10)
train_start = pd.Timestamp("2013")
valid_start = pd.Timestamp("2016")
test_start = pd.Timestamp("2017")
train_df = df[(df.index >= train_start) & (df.index < valid_start)].copy()
valid_df = df[(df.index >= valid_start) & (df.index < test_start)].copy()
test_df = df[(df.index >= test_start)].copy()


def scaler(target_feature):
    scaler_input = StandardScaler()
    scaler_output = StandardScaler()

    scaled_train = scaler_input.fit_transform(train_df)
    target_train = scaler_output.fit_transform(train_df[[target_feature]])
    scaled_valid = scaler_input.transform(valid_df)
    target_valid = scaler_output.transform(valid_df[[target_feature]])
    scaled_test = scaler_input.transform(test_df)
    target_test = scaler_output.transform(test_df[[target_feature]])

    return scaled_train,target_train,scaled_valid,target_valid,scaled_test,target_test, scaler_output

def process_Xy(raw_X: np.array, raw_y: np.array, lookback: int) -> np.array:
        X = np.empty(shape=(raw_X.shape[0] - lookback, lookback , raw_X.shape[1]), dtype=np.float32)
        y = np.empty(shape=(raw_y.shape[0] - lookback), dtype=np.float32)

        target_index = 0
        for i in range(lookback, raw_X.shape[0]):
            X[target_index] = raw_X[i - lookback : i]
            y[target_index] = raw_y[i]
            target_index += 1

        return X.copy(), y.copy()



def model_weather_definition(train_X, train_y, valid_X, valid_y):

    # model = keras.Sequential(
    #     [
    #         layers.LSTM(16, activation="relu", input_shape = train_X.shape[1:]),
    #         layers.Dense(1),
    #     ]
    # )
    model = keras.Sequential([
        layers.GRU(16, activation='relu', input_shape=train_X.shape[1:], return_sequences=True),
        layers.GRU(8, activation='relu', return_sequences=False),
        layers.Dense(16, activation='relu'),
        layers.Dense(8, activation='relu'),
        layers.Dense(1)
    ])

    model.compile(loss='mean_squared_error', optimizer='adam')


    callbacks = [EarlyStopping(monitor='val_loss', patience=10)]

    history = model.fit(
        train_X,
        train_y,
        validation_data=(valid_X, valid_y),
        batch_size=16,
        epochs=100,
        callbacks=callbacks,
        shuffle=True,
        verbose=True,
    )

    return model, history

targ_feature = "meantemp"
scaled_train,target_train,scaled_valid,target_valid,scaled_test,target_test,scaler_output = scaler(targ_feature)
lookback = 10
train_X, train_y = process_Xy(scaled_train, target_train, lookback=lookback)
valid_X, valid_y = process_Xy(scaled_valid, target_valid, lookback=lookback)
test_X, test_y = process_Xy(scaled_test, target_test, lookback=lookback)
model, history = model_weather_definition(train_X, train_y,valid_X, valid_y)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
pred = model.predict(test_X)
plt.figure(figsize=(10, 6))
plt.plot(test_df[targ_feature], label="Real", color='blue')
plt.plot(pd.DataFrame(index=test_df.index[lookback:], data=scaler_output.inverse_transform(pred)), label="Predicted", color='red')
plt.xticks(rotation=45)
plt.title('Actual vs Predicted' + targ_feature)
plt.xlabel('Date')
plt.ylabel(targ_feature)
plt.legend()
plt.show()
# Out:
# 1575
# Outliers:
# date
# 2016-03-28    7679.333333
# 2016-08-02     310.437500
# 2016-08-14     633.900000
# 2016-08-16      -3.041667
# 2016-11-28      12.045455
# 2017-01-01      59.000000
# Name: meanpressure, dtype: float64
# <ipython-input-40-7116a1b00fc4>:64: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[target_index] = raw_y[i]
# Epoch 1/100
# 68/68 [==============================] - 6s 17ms/step - loss: 0.5812 - val_loss: 0.5743
# Epoch 2/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.2296 - val_loss: 0.2761
# Epoch 3/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0909 - val_loss: 0.1907
# Epoch 4/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0686 - val_loss: 0.1499
# Epoch 5/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0633 - val_loss: 0.1295
# Epoch 6/100
# 68/68 [==============================] - 1s 12ms/step - loss: 0.0573 - val_loss: 0.1260
# Epoch 7/100
# 68/68 [==============================] - 1s 15ms/step - loss: 0.0536 - val_loss: 0.1146
# Epoch 8/100
# 68/68 [==============================] - 1s 16ms/step - loss: 0.0504 - val_loss: 0.1133
# Epoch 9/100
# 68/68 [==============================] - 1s 13ms/step - loss: 0.0498 - val_loss: 0.1010
# Epoch 10/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0481 - val_loss: 0.1241
# Epoch 11/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0480 - val_loss: 0.1150
# Epoch 12/100
# 68/68 [==============================] - 1s 11ms/step - loss: 0.0456 - val_loss: 0.1043
# Epoch 13/100
# 68/68 [==============================] - 1s 11ms/step - loss: 0.0449 - val_loss: 0.1297
# Epoch 14/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0449 - val_loss: 0.1152
# Epoch 15/100
# 68/68 [==============================] - 1s 11ms/step - loss: 0.0448 - val_loss: 0.1094
# Epoch 16/100
# 68/68 [==============================] - 1s 12ms/step - loss: 0.0435 - val_loss: 0.1305
# Epoch 17/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0438 - val_loss: 0.1182
# Epoch 18/100
# 68/68 [==============================] - 1s 10ms/step - loss: 0.0425 - val_loss: 0.1369
# Epoch 19/100
# 68/68 [==============================] - 1s 12ms/step - loss: 0.0424 - val_loss: 0.1369
# 4/4 [==============================] - 0s 4ms/step

# %% [markdown]
# **Exercise +1**

# %% [markdown]
# We can omit the "day-of-the-week" analysis in our temperature prediction model because temperature variations are primarily influenced by seasonal changes rather than weekly cycles.
#
# By focusing on the day of the year instead of the day of the week, we can capture the seasonal changes in temperature more effectively. The day of the year encapsulates the annual cycle of temperature fluctuations, including the transitions between different seasons. This approach allows the model to learn from the consistent and significant temperature changes that occur throughout the year, aligning with the natural progression of weather patterns.
#
# In contrast, incorporating the day of the week as a feature might introduce unnecessary complexity and noise into the model. Weekly temperature patterns may not be as consistent or relevant for temperature prediction compared to seasonal variations. Additionally, the day of the week may not directly correlate with temperature fluctuations, especially in regions where weather patterns are predominantly influenced by seasonal changes rather than weekly cycles.
#
# Therefore, to build a more accurate and meaningful temperature prediction model, it is advisable to omit the "day-of-the-week" analysis and instead focus on capturing the seasonal variations in temperature using features such as the day of the year.
